# %% [markdown]
# ### Controlling Exceptions: %xmode

# %%
def func1(a, b):
    return a / b

def func2(x):
    a= x
    b= x-1
    return func1(a, b)

# %%
func2(1)
# Out:
# ----------------------------------------------------------------
# ZeroDivisionError              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 func2(1)
#
# Cell In[1], line 7, in func2(x)
#       5 a= x
#       6 b= x-1
# ----> 7 return func1(a, b)
#
# Cell In[1], line 2, in func1(a, b)
#       1 def func1(a, b):
# ----> 2     return a / b
#
# ZeroDivisionError: division by zero

# %%
# %xmode Plain

# %%
func2(1)

# %%
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
func2(1)
# Out:
# ----------------------------------------------------------------
# ZeroDivisionError              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 func2(1)
#
# Cell In[1], line 7, in func2(x=1)
#       5 a= x
#       6 b= x-1
# ----> 7 return func1(a, b)
#         a = 1
#         b = 0
# Cell In[1], line 2, in func1(a=1, b=0)
#       1 def func1(a, b):
# ----> 2     return a / b
#         a = 1
#         b = 0
# ZeroDivisionError: division by zero

# %%
# %debug
# Out:
# > c:\users\a\appdata\local\temp\ipykernel_4004\3726590381.py(2)func1()
# ipdb>  print(a)
# 1
# ipdb>  print(b)
# 0
# ipdb>  quit

# %%
# %debug
# Out:
# > c:\users\a\appdata\local\temp\ipykernel_4004\3726590381.py(2)func1()
# ipdb>  up
# > c:\users\a\appdata\local\temp\ipykernel_4004\3726590381.py(7)func2()
# ipdb>  print(x)
# 1
# ipdb>  up
# > c:\users\a\appdata\local\temp\ipykernel_4004\2483606204.py(1)<module>()
# ipdb>  down
# > c:\users\a\appdata\local\temp\ipykernel_4004\3726590381.py(7)func2()
# ipdb>  quit

# %%
# %xmode Plain
# %pdb on
func2(1)
# Out:
# Exception reporting mode: Plain
# Automatic pdb calling has been turned ON
# Traceback (most recent call last):
#
#   Cell In[8], line 3
#     func2(1)
#
#   Cell In[1], line 7 in func2
#     return func1(a, b)
#
#   Cell In[1], line 2 in func1
#     return a / b
#
# ZeroDivisionError: division by zero
# > c:\users\a\appdata\local\temp\ipykernel_4004\3726590381.py(2)func1()
# ipdb>  print(b)
# 0
# ipdb>  quit
